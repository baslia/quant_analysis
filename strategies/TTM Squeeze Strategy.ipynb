# %% [markdown]
# # TTM Squeeze Strategy
# _Roshan Mahes (based on Larry Kubin's tutorial)._

# %% [markdown]
# This strategy is based on Larry Kubin's following tutorial:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('YhkNoOqYp9A', width=533, height=300)

# %%
# %pip install pandas
# %pip install yfinance
# %pip install plotly
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: yfinance in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (0.2.32)
# Requirement already satisfied: pandas>=1.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from yfinance) (1.26.2)
# Requirement already satisfied: requests>=2.31 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from yfinance) (2.3.9)
# Requirement already satisfied: peewee>=3.16.2 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: plotly in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/envs/py311/lib/python3.11/site-packages (from plotly) (23.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# The following packages are required:

# %%
import os
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

# %%
# Get current wd
os.getcwd()
# Get the parent wd
path = os.path.dirname(os.getcwd())

# %% [markdown]
# In the file `Amsterdam.csv` we provided a list of companies listed in the _Amsterdam Exchange Index_ (AEX), _Amsterdam Midcap Index_ (AEX) and _Amsterdam Small Cap Index_ (AScX):

# %%
Amsterdam_df = pd.read_csv(path + '/data/Amsterdam.csv', sep=';')
Amsterdam_df
# Out:
#       Symbol               Company Name Last Price  Change % Change  \
# 0      NN.AS              NN Group N.V.      32.75   0.070   +0.21%
# 1     WKL.AS        Wolters Kluwer N.V.      68.20  -0.320   -0.47%
# 2    RDSA.AS      Royal Dutch Shell plc      12.26  -0.060   -0.47%
# 3    AKZA.AS            Akzo Nobel N.V.      81.66  -0.400   -0.49%
# 4    IMCD.AS                  IMCD N.V.      88.16  -0.640   -0.72%
# ..       ...                        ...        ...     ...      ...
# 70     KA.AS                      KA.AS        NaN     NaN      NaN
# 71  BINCK.AS                   BINCK.AS        NaN     NaN      NaN
# 72   BRNL.AS  Brunel International N.V.       6.40  -0.100   -1.54%
# 73    TMG.AS                     TMG.AS        NaN     NaN      NaN
# 74     PB9.F   Vivoryon Therapeutics AG     48.150  -0.485   -9.15%
#
#         Volume
# 0    1,426,693
# 1      659,034
# 2   14,257,842
# 3      493,146
# 4       135,69
# ..         ...
# 70         NaN
# 71         NaN
# 72      65,573
# 73         NaN
# 74       3,122
#
# [75 rows x 6 columns]

# %% [markdown]
# We will use these stocks to test our strategy on. First we need to download the corresponding daily stock prices, starting from January 1st, 2020:

# %%
symbols = Amsterdam_df['Symbol']

# keep track of the number of indices downloaded
symbol_index = 0

today = pd.Timestamp.today().strftime('%Y-%m-%d')
# 90 days ago
start = (pd.Timestamp.today() - pd.Timedelta(days=365)).strftime('%Y-%m-%d')

for symbol in symbols:
    
    symbol_index += 1
    print(f'Downloading symbol {symbol_index}/{len(symbols)}: {symbol}.')
    data = yf.download(symbol, start=start, end=today)
    
    # don't store empty datasets
    if len(data):
        data.to_csv(f'{path}/data/{symbol}.csv')
# Out:
# Downloading symbol 1/75: NN.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 2/75: WKL.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 3/75: RDSA.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['RDSA.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 4/75: AKZA.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 5/75: IMCD.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 6/75: PHIA.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 7/75: RAND.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 8/75: AGN.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 9/75: DSM.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['DSM.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 10/75: AD.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 11/75: ASRNL.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 12/75: REN.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 13/75: ADYEN.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 14/75: HEIA.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 15/75: INGA.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 16/75: UNA.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 17/75: MT.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 18/75: URW.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['URW.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 19/75: TKWY.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 20/75: ABN.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 21/75: PRX.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 22/75: KPN.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 23/75: ASML.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 24/75: GLPG.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 25/75: ASM.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 26/75: SBMO.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 27/75: PNL.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 28/75: AF.PA.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 29/75: FAGR.BR.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 30/75: TWEKA.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 31/75: AALB.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 32/75: FLOW.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 33/75: BOKA.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['BOKA.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 34/75: ARCAD.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 35/75: ECMPA.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 36/75: PHARM.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 37/75: ATC.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ATC.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 38/75: BAMNB.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 39/75: OCI.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 40/75: BFIT.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 41/75: APAM.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 42/75: LIGHT.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 43/75: NSI.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 44/75: VPK.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 45/75: GVNV.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['GVNV.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 46/75: FUR.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 47/75: CRBN.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 48/75: INTER.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['INTER.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 49/75: WDP.BR.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 50/75: BESI.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 51/75: FAGR.BR.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 52/75: ACOMO.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 53/75: NEDAP.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 54/75: BOLS.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 55/75: BBED.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 56/75: VALUE.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 57/75: ICT.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ICT.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 58/75: STRN.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['STRN.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 59/75: 10601345.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['10601345.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 60/75: BRILL.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 61/75: HOLCO.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 62/75: KENDR.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 63/75: ACCEL.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ACCEL.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 64/75: ORDI.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ORDI.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 65/75: DPA.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['DPA.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 66/75: KDS.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['KDS.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 67/75: NEWAY.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['NEWAY.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 68/75: AMG.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 69/75: LANS.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['LANS.AS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-01-29 -> 2024-01-29)')
# Downloading symbol 70/75: AND.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['AND.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 71/75: KA.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['KA.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 72/75: BINCK.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['BINCK.AS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Downloading symbol 73/75: BRNL.AS.
# [*********************100%%**********************]  1 of 1 completed
# Downloading symbol 74/75: TMG.AS.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['TMG.AS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-01-29 -> 2024-01-29)')
# Downloading symbol 75/75: PB9.F.
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['PB9.F']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %% [markdown]
# ## The Strategy
#
# _Volatility channels_ are a type of indicator that plot volatility-related lines above and below the market. These lines are variously known as channels, envelopes, or bands. They widen as volatility increases, and narrow as volatility decreases. The most well-known volatility channel are the _Bollinger Bands,_ though the _Keltner Channel_ Indicator is another effective type as well.
#
# The channels or bands describe the outer boundaries of the normality of the price change. It also establishes where a band of likely support or resistance levels might lie. If the market breaks out beyond this boundary, we are alerted of an unusual occurrence and can plan our trades accordingly. There are numerous ways of using these bands to generate trade signals such as _Squeeze, Bounce, Walking the Bands, M-Tops_ and _W-Bottoms_ etc. We’ll be using a very effective method of detecting a change in the volatility of the market using the squeeze of Bollinger Bands and Keltner Channels, called the _TTM Squeeze indicator_.
#
# ### Bollinger Bands
#
# Bollinger Bands, developed by John Bollinger, combine moving averages and standard deviations to detect a change in volatility of the market. There are three components to the Bollinger Band indicator:
#
# - _Middle Line:_ $\text{20-day Simple Moving Average (SMA)}$
# - _Upper Band:_ $\text{20-day SMA} + 2 \cdot Std$
# - _Lower Band:_ $\text{20-day SMA} - 2 \cdot Std$
#
# Because _standard deviation ($Std$)_ is a measure of volatility, when the markets become more volatile the bands widen while during less volatile periods, the bands contract. Many traders believe the closer the prices move to the upper band, the more overbought the market, and the closer the prices move to the lower band, the more oversold the market.
#
#
# ### Keltner's Channel
#
# The Keltner Channel, invented by Chester Keltner, is also a volatility based technical indicator composed of three separate lines. Instead of using the standard deviation, Keltner Channels use the _Average True Range ($ATR$)_ to set channel distance. This is the $20$-day moving average of the absolute price difference each day. The following are the three components:
#
# - _Middle Line:_ $\text{20-day Exponential Moving Average (EMA)}$
# - _Upper Channel Line:_ $\text{20-day EMA} + 1.5 \cdot ATR$
# - _Lower Channel Line:_ $\text{20-day EMA} - 1.5 \cdot ATR$
#
# Keltner Channels and Bollinger Bands are quite similar. The general concept is that the farther the closing price is from the average closing price, the more volatile a market is deemed to be, and vice versa. That is what determines the degree of contraction or expansion of a Bollinger Band or a Keltner Channel.
#
# ### TTM Squeeze indicator
# The strategy works as follows. The TTM Squeeze indicator measures the relationship between the Bollinger Bands and Keltner's Channel. When the volatility increases, so does the distance between the bands, and conversely, when the volatility declines, the distance also decreases.  The Squeeze indicator finds sections of the Bollinger Bands study which fall inside the Keltner's Channels.
#
# At the moment this squeeze happens, a price breakout from the upper Bollinger Band would indicate the possibility of an uptrend in the future. This is backed by the fact that once the price starts breaking out of the bands, it would mean a relaxation of the squeeze and the possibility of high market volatility and price movement in the future. Similarly, a price breakout from the lower Bollinger Band after a squeeze would indicate the possibility of a downtrend in the future and an increased market volatility in the same direction. When the market finishes a move, the indicator turns off, which corresponds to bands having pushed well outside the range of Keltner's Channels.
#
# Now let's implement the strategy, and apply it to the Amsterdam stocks:

# %%
for filename in os.listdir(f'{path}/data'):
    # print(filename)
    if len(filename.split(".")) != 3:
        # skip the file that does not contain two dots
        continue
    
    # check whether the stock is from Amsterdam
    if filename.split(".")[1] == 'AS':
        
        # load data
        symbol = filename.split(".")[0] + '.AS'
        df = pd.read_csv(f'{path}/data/{symbol}.csv')

        # compute Bollinger bands
        df['20sma'] = df['Close'].rolling(window=20).mean()
        df['std'] = df['Close'].rolling(window=20).std()

        df['low_bol'] = df['20sma'] - (2 * df['std'])
        df['upp_bol'] = df['20sma'] + (2 * df['std'])

        # compute Keltner's channel
        df['TR'] = df['High'] - df['Low']
        df['ATR'] = df['TR'].rolling(window=20).mean()
        
        df['low_kel'] = df['20sma'] - df['ATR'] * 1.5
        df['upp_kel'] = df['20sma'] + df['ATR'] * 1.5

        # squeeze indicator
        def in_squeeze(df):
            return df['low_kel'] < df['low_bol'] < df['upp_bol'] < df['upp_kel']

        df['squeeze'] = df.apply(in_squeeze, axis=1)

        # stock is coming out of the squeeze
        if df.iloc[-3]['squeeze'] and not df.iloc[-1]['squeeze']:
            
            # decide which action to take by comparing distances                
            distance_to_upper = abs(df['upp_bol'].values[-1] - df['Close'].values[-1])
            distance_to_lower = abs(df['low_bol'].values[-1] - df['Close'].values[-1])
            
            if distance_to_upper < distance_to_lower:
                action = 'buy'
            else:
                action = 'sell'
            
            print(f'{symbol} is coming out of the squeeze. Advice: {action} stock.')
              
            # initialize figure
            df = df.iloc[20:]
            
            candles = go.Candlestick(x=df['Date'], open=df['Open'], high=df['High'],
                                     low=df['Low'], close=df['Close'], name='candles')

            upp_bol = go.Scatter(x=df['Date'], y=df['upp_bol'], name='Upper Bollinger Band', line={'color': 'darkblue'},
                                 fill='tonexty', fillcolor='rgba(0,0,255,0.1)')
            low_bol = go.Scatter(x=df['Date'], y=df['low_bol'], name='Lower Bollinger Band', line={'color': 'darkblue'})

            upp_kel = go.Scatter(x=df['Date'], y=df['upp_kel'], name='Upper Keltner Channel', line={'color': 'darkred'},
                                 fill='tonexty', fillcolor='rgba(255,0,0,0.1)')
            low_kel = go.Scatter(x=df['Date'], y=df['low_kel'], name='Lower Keltner Channel', line={'color': 'darkred'})
            
            # show figure
            fig = go.Figure(data=[candles, low_bol, upp_bol, low_kel, upp_kel])
            fig.layout.xaxis.type = 'category' # remove weekend days
            fig.layout.xaxis.rangeslider.visible = False
            fig.layout.xaxis.dtick = 20 # show x-axis ticker once a month
            
            company_name = Amsterdam_df[Amsterdam_df['Symbol'] == symbol]['Company Name'].values[0]
            fig.layout.title = f'{company_name} ({symbol}). Action: {action} stock.'
            fig.layout.template = 'plotly_white'
            fig.show()
# Out:
# ARCAD.AS is coming out of the squeeze. Advice: buy stock.
# <div>                            <div id="42b606a7-c1ec-4cad-a51d-2096a71c6989" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42b606a7-c1ec-4cad-a51d-2096a71c6989")) {                    Plotly.newPlot(                        "42b606a7-c1ec-4cad-a51d-2096a71c6989",                        [{"close":[40.119998931884766,39.20000076293945,39.279998779296875,39.31999969482422,39.900001525878906,39.720001220703125,39.599998474121094,39.5,39.779998779296875,39.2400016784668,37.619998931884766,38.02000045776367,37.20000076293945,37.70000076293945,36.91999816894531,37.400001525878906,37.7400016784668,37.939998626708984,38.15999984741211,35.900001525878906,36.52000045776367,36.47999954223633,37.040000915527344,37.599998474121094,37.7599983215332,38.2400016784668,38.099998474121094,37.119998931884766,36.97999954223633,37.099998474121094,37.2599983215332,36.41999816894531,36.84000015258789,37.31999969482422,37.380001068115234,37.58000183105469,38.0