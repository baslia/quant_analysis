# %%
# Step 1: Get data from OpenBB

# Start by importing pandas, the OpenBB SDK, QuantStats, and Backtrader.

import datetime as dt

import pandas as pd

from openbb_terminal.sdk import openbb
import quantstats as qs
import backtrader as bt
# There’s an unsolved issue with Backtrader that prevents it from downloading data. Here’s a simple workaround.

def openbb_data_to_bt_data(symbol, start_date, end_date):

    df = openbb.stocks.load(symbol, start_date=start_date, end_date=end_date)

    fn = f"data/{symbol.lower()}.csv"
    df.to_csv(fn)

    return bt.feeds.YahooFinanceCSVData(
        dataname=fn,
        fromdate=dt.datetime.strptime(start_date, '%Y-%m-%d'),
        todate=dt.datetime.strptime(end_date, '%Y-%m-%d')
    )
# This function downloads the data from the OpenBB SDK, converts it to a CSV, and reads it into Backtrader’s YahooFinanceCSVData.

# %%
# Step 2: Build a backtest using Backtrader

# Fund managers report their holdings every month. They don’t want to tell investors they lost money on the latest meme stock. So they sell them before the reporting deadline and buy higher-quality assets, like bonds.

# You might be able to take advantage of this effect by buying bonds toward the end of the month and selling them at the beginning.

# Start with a simple helper function that gets the last day of the month.

def last_day_of_month(any_day):
    # The day 28 exists in every month. 4 days later, it's always next month
    next_month = any_day.replace(day=28) + dt.timedelta(days=4)

    # subtracting the number of the current day brings us back one month
    return (next_month - dt.timedelta(days=next_month.day)).day
# Next, setup the Backtrader strategy. All Backtrader strategies are built as classes and inherit bt.Strategy.

# %%
class MonthlyFlows(bt.Strategy):

    params = (
        ("end_of_month", 23),
        ("start_of_month", 7),
    )

    def __init__(self):
        self.order = None
        self.dataclose = self.datas[0].close

    def notify_order(self, order):
        # No more orders
        self.order = None

    def next(self):

        # Get today's date, day of month, and last day of current month
        dt_ = self.datas[0].datetime.date(0)
        dom = dt_.day
        ldm = last_day_of_month(dt_)

        # If an order is pending, exit
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # We're in the first week of the month, sell
            if dom <= self.params.start_of_month:

                # Sell the entire portfolio
                self.order = self.order_target_percent(target=-1)

                print(f"Created SELL of {self.order.size} at {self.data_close[0]} on day {dom}")

            # We're in the last week of the month, buy
            if dom >= self.params.end_of_month:

                # Buy the entire portfolio
                self.order = self.order_target_percent(target=1)

                print(f"Created BUY of {self.order.size} {self.data_close[0]} on day {dom}")

        # We are not in the market
        else:

            # If we're long
            if self.position.size > 0:

                # And not within the last week of the month, close
                if not self.params.end_of_month <= dom <= ldm:

                    print(f"Created CLOSE of {self.position.size} at {self.data_close[0]} on day {dom}")

                    self.order = self.order_target_percent(target=0.0)

            # If we're short
            if self.position.size < 0:

                # And not within the first week of the month, close
                if not 1 <= dom <= self.params.start_of_month:

                    print(f"Created CLOSE of {self.position.size} at {self.data_close[0]} on day {dom}")

                    # self.order = self.close()
                    self.order = self.order_target_percent(target=0.0)

# %% [markdown]
# First, set up the strategy parameters. end_of_month is the first day I want to be long TLT and start_of_month is the last day I want to be short.
#
# The strategy logic is in the next method.
#
# This code tests if there’s a position in the market. If not, it checks if the current day is within the first week of the month and creates a short position. Otherwise, if the current day is within the last week, it creates a long position.
#
# The last step closes the open positions.
#
# The strategy closes the long position if the current day is no longer within the last week of the month. The strategy closes the short position if the current day is no longer within the first week of the month.
#
# Now, run the backtest.

# %%
data = openbb_data_to_bt_data(
    "TLT",
    start_date="2002-01-01",
    end_date="2022-06-30"
)

cerebro = bt.Cerebro(stdstats=False)

cerebro.adddata(data)
cerebro.broker.setcash(1000.0)

cerebro.addstrategy(MonthlyFlows)

cerebro.addobserver(bt.observers.Value)

cerebro.addanalyzer(
    bt.analyzers.Returns, _name="returns"
)
cerebro.addanalyzer(
    bt.analyzers.TimeReturn, _name="time_return"
)

backtest_result = cerebro.run()
# Out:
# Loading Daily data for TLT with starting period 2002-07-30.
# Created BUY of 24 40.82 on day 30
# Created CLOSE of 24 at 41.56 on day 1
# Created SELL of -24 at 41.99 on day 2
# Created CLOSE of -24 at 41.91 on day 8
# Created BUY of 23 43.02 on day 23
# Created CLOSE of 23 at 44.28 on day 3
# Created SELL of -23 at 44.27 on day 4
# Created CLOSE of -23 at 43.92 on day 9
# Created BUY of 23 45.31 on day 23
# Created CLOSE of 23 at 44.9 on day 1
# Created SELL of -23 at 45.16 on day 2
# Created CLOSE of -23 at 45.28 on day 8
# Created BUY of 24 42.57 on day 23
# Created CLOSE of 24 at 43.6 on day 1
# Created SELL of -24 at 43.41 on day 4
# Created CLOSE of -24 at 44.85 on day 8
# Created BUY of 23 43.55 on day 25
# Created CLOSE of 23 at 43.42 on day 2
# Created SELL of -23 at 43.48 on day 3
# Created CLOSE of -23 at 44.14 on day 9
# Created BUY of 22 44.52 on day 23
# Created CLOSE of 22 at 44.17 on day 2
# Created SELL of -22 at 44.28 on day 3
# Created CLOSE of -22 at 44.54 on day 8
# Created BUY of 22 44.77 on day 23
# Created CLOSE of 22 at 45.15 on day 3
# Created SELL of -22 at 45.35 on day 4
# Created CLOSE of -22 at 45.11 on day 10
# Created BUY of 22 45.58 on day 24
# Created CLOSE of 22 at 46.54 on day 3
# Created SELL of -22 at 46.57 on day 4
# Created CLOSE of -22 at 46.95 on day 10
# Created BUY of 22 45.08 on day 24
# Created CLOSE of 22 at 45.72 on day 1
# Created SELL of -22 at 45.24 on day 2
# Created CLOSE of -22 at 45.34 on day 8
# Created BUY of 22 45.54 on day 23
# Created CLOSE of 22 at 46.35 on day 1
# Created SELL of -22 at 45.99 on day 2
# Created CLOSE of -22 at 47.12 on day 8
# Created BUY of 20 49.91 on day 23
# Created CLOSE of 20 at 48.89 on day 2
# Created SELL of -20 at 49.29 on day 3
# Created CLOSE of -20 at 49.55 on day 9
# Created BUY of 20 49.31 on day 23
# Created CLOSE of 20 at 48.13 on day 1
# Created SELL of -20 at 48.25 on day 2
# Created CLOSE of -20 at 47.29 on day 8
# Created BUY of 21 45.43 on day 23
# Created CLOSE of 21 at 43.51 on day 1
# Created SELL of -21 at 43.88 on day 4
# Created CLOSE of -21 at 44.11 on day 8
# Created BUY of 21 43.62 on day 25
# Created CLOSE of 21 at 43.46 on day 2
# Created SELL of -21 at 43.53 on day 3
# Created CLOSE of -21 at 44.07 on day 8
# Created BUY of 20 45.3 on day 23
# Created CLOSE of 20 at 46.55 on day 1
# Created SELL of -20 at 46.34 on day 2
# Created CLOSE of -20 at 45.02 on day 8
# Created BUY of 21 44.85 on day 23
# Created CLOSE of 21 at 45.09 on day 3
# Created SELL of -21 at 45.35 on day 4
# Created CLOSE of -21 at 44.55 on day 10
# Created BUY of 21 45.81 on day 24
# Created CLOSE of 21 at 45.21 on day 1
# Created SELL of -21 at 45.4 on day 2
# Created CLOSE of -21 at 45.72 on day 8
# Created BUY of 21 46.07 on day 23
# Created BUY of 20 46.51 on day 24
# Created CLOSE of 20 at 45.53 on day 2
# Created SELL of -20 at 45.41 on day 5
# Created CLOSE of -20 at 46.08 on day 8
# Created BUY of 19 47.11 on day 23
# Created CLOSE of 19 at 46.83 on day 2
# Created SELL of -19 at 47.07 on day 3
# Created CLOSE of -19 at 47.45 on day 9
# Created BUY of 19 47.58 on day 23
# Created CLOSE of 19 at 47.98 on day 1
# Created SELL of -19 at 47.68 on day 2
# Created CLOSE of -19 at 49.02 on day 8
# Created BUY of 17 49.54 on day 23
# Created CLOSE of 17 at 48.52 on day 1
# Created SELL of -18 at 47.32 on day 2
# Created CLOSE of -18 at 46.96 on day 8
# Created BUY of 18 45.86 on day 23
# Created CLOSE of 18 at 45.7 on day 3
# Created SELL of -18 at 45.39 on day 4
# Created CLOSE of -18 at 44.45 on day 10
# Created BUY of 19 44.92 on day 24
# Created CLOSE of 19 at 45.11 on day 1
# Created SELL of -19 at 44.99 on day 2
# Created CLOSE of -19 at 44.92 on day 8
# Created BUY of 19 45.4 on day 23
# Created CLOSE of 19 at 46.09 on day 1
# Created SELL of -19 at 46.58 on day 2
# Created CLOSE of -19 at 46.54 on day 8
# Created BUY of 19 46.91 on day 23
# Created CLOSE of 19 at 46.77 on day 2
# Created SELL of -19 at 46.96 on day 3
# Created CLOSE of -19 at 47.74 on day 9
# Created BUY of 18 47.7 on day 23
# Created CLOSE of 18 at 48.71 on day 1
# Created SELL of -18 at 48.23 on day 2
# Created CLOSE of -18 at 48.59 on day 8
# Created BUY of 18 49.71 on day 23
# Created CLOSE of 18 at 48.87 on day 1
# Created SELL of -17 at 48.94 on day 4
# Created CLOSE of -17 at 49.15 on day 8
# Created BUY of 17 50.24 on day 25
# Created CLOSE of 17 at 49.67 on day 1
# Created SELL of -17 at 49.75 on day 2
# Created CLOSE of -17 at 49.1 on day 8
# Created BUY of 17 49.85 on day 23
# Created CLOSE of 17 at 48.71 on day 1
# Created SELL of -17 at 48.51 on day 2
# Created CLOSE of -17 at 50.27 on day 8
# Created BUY of 16 49.92 on day 23
# Created CLOSE of 16 at 50.19 on day 3
# Created SELL of -16 at 49.67 on day 4
# Created CLOSE of -16 at 50.16 on day 10
# Created BUY of 16 51.7 on day 24
# Created CLOSE of 16 at 51.79 on day 1
# Created SELL of -15 at 51.91 on day 2
# Created CLOSE of -15 at 53.29 on day 8
# Created BUY of 15 51.53 on day 23
# Created CLOSE of 15 at 51.09 on day 1
# Created SELL of -15 at 51.02 on day 2
# Created CLOSE of -15 at 51.26 on day 8
# Created BUY of 15 50.17 on day 23
# Created CLOSE of 15 at 51.05 on day 1
# Created SELL of -15 at 51.04 on day 4
# Created CLOSE of -15 at 50.85 on day 8
# Created BUY of 15 52.44 on day 25
# Created CLOSE of 15 at 52.83 on day 2
# Created SELL of -15 at 52.97 on day 3
# Created CLOSE of -15 at 52.29 on day 9
# Created BUY of 15 54.02 on day 23
# Created CLOSE of 15 at 55.17 on day 1
# Created SELL of -15 at 55.3 on day 2
# Created CLOSE of -15 at 55.31 on day 8
# Created BUY of 15 55.22 on day 23
# Created CLOSE of 15 at 55.0 on day 1
# Created SELL of -15 at 54.48 on day 5
# Created CLOSE of -15 at 54.68 on day 8
# Created BUY of 15 53.85 on day 25
# Created CLOSE of 15 at 53.6 on day 1
# Created SELL of -15 at 53.42 on day 2
# Created CLOSE of -15 at 53.06 on day 8
# Created BUY of 15 54.58 on day 23
# Created CLOSE of 15 at 55.33 on day 1
# Created SELL of -15 at 55.38 on day 2
# Created CLOSE of -15 at 54.53 on day 8
# Created BUY of 15 53.89 on day 23
# Created CLOSE of 15 at 53.24 on day 3
# Created SELL of -15 at 53.41 on day 4
# Created CLOSE of -15 at 53.62 on day 10
# Created BUY of 15 53.0 on day 24
# Created CLOSE of 15 at 52.39 on day 1
# Created SELL of -16 at 52.15 on day 2
# Created CLOSE of -16 at 52.39 on day 8
# Created BUY of 15 52.92 on day 23
# Created CLOSE of 15 at 52.73 on day 1
# Created SELL of -15 at 52.75 on day 2
# Created CLOSE of -15 at 53.19 on day 8
# Created BUY of 15 54.11 on day 23
# Created CLOSE of 15 at 54.32 on day 3
# Created SELL of -15 at 54.45 on day 4
# Created CLOSE of -15 at 54.32 on day 9
# Created BUY of 15 54.66 on day 23
# Created CLOSE of 15 at 53.48 on day 1
# Created SELL of -15 at 53.58 on day 2
# Created CLOSE of -15 at 53.69 on day 8
# Created BUY of 14 54.16 on day 23
# Created CLOSE of 14 at 53.93 on day 1
# Created SELL of -14 at 53.55 on day 2
# Created CLOSE of -14 at 52.8 on day 8
# Created BUY of 15 52.71 on day 23
# Created CLOSE of 15 at 51.79 on day 3
# Created SELL of -15 at 51.74 on day 4
# Created CLOSE of -15 at 51.01 on day 10
# Created BUY of 15 50.94 on day 24
# Created CLOSE of 15 at 49.97 on day 1
# Created SELL of -15 at 50.11 on day 2
# Created CLOSE of -15 at 50.24 on day 8
# Created BUY of 15 50.79 on day 23
# Created CLOSE of 15 at 50.48 on day 1
# Created SELL of -15 at 51.13 on day 2
# Created CLOSE of -15 at 51.42 on day 8
# Created BUY of 15 50.31 on day 23
# Created CLOSE of 15 at 50.8 on day 3
# Created SELL of -15 at 50.39 on day 5
# Created CLOSE of -15 at 51.08 on day 10
# Created BUY of 15 51.63 on day 24
# Created CLOSE of 15 at 51.94 on day 1
# Created SELL of -15 at 52.14 on day 2
# Created CLOSE of -15 at 52.38 on day 8
# Created BUY of 14 52.97 on day 23
# Created CLOSE of 14 at 53.55 on day 1
# Created SELL of -14 at 53.22 on day 5
# Created CLOSE of -14 at 53.29 on day 8
# Created BUY of 14 55.11 on day 25
# Created CLOSE of 14 at 54.71 on day 2
# Created SELL of -14 at 54.64 on day 3
# Created CLOSE of -14 at 54.23 on day 9
# Created BUY of 14 53.42 on day 23
# Created CLOSE of 14 at 55.33 on day 1
# Created SELL of -14 at 55.1 on day 2
# Created CLOSE of -14 at 55.06 on day 8
# Created BUY of 14 55.73 on day 24
# Created CLOSE of 14 at 56.44 on day 1
# Created SELL of -14 at 56.54 on day 4
# Created CLOSE of -14 at 55.71 on day 8
# Created BUY of 14 55.35 on day 26
# Created CLOSE of 14 at 55.17 on day 3
# Created SELL of -14 at 55.5 on day 4
# Created CLOSE of -14 at 55.36 on day 8
# Created BUY of 15 54.27 on day 23
# Created CLOSE of 15 at 54.17 on day 1
# Created SELL of -15 at 54.23 on day 2
# Created CLOSE of -15 at 54.81 on day 8
# Created BUY of 14 55.25 on day 23
# Created CLOSE of 14 at 56.03 on day 1
# Created SELL of -14 at 56.31 on day 2
# Created CLOSE of -14 at 56.41 on day 8
# Created BUY of 15 55.43 on day 23
# Created CLOSE of 15 at 55.21 on day 2
# Created SELL of -15 at 55.14 on day 3
# Created CLOSE of -15 at 54.62 on day 9
# Created BUY of 15 55.44 on day 23
# Created CLOSE of 15 at 55.65 on day 1
# Created SELL of -15 at 55.62 on day 2
# Created CLOSE of -15 at 55.75 on day 8
# Created BUY of 15 54.4 on day 23
# Created CLOSE of 15 at 54.04 on day 1
# Created SELL of -15 at 54.29 on day 4
# Created CLOSE of -15 at 52.91 on day 8
# Created BUY of 16 53.18 on day 25
# Created CLOSE of 16 at 54.06 on day 2
# Created SELL of -16 at 53.73 on day 3
# Created CLOSE of -16 at 53.1 on day 9
# Created BUY of 15 54.4 on day 23
# Created CLOSE of 15 at 55.44 on day 1
# Created SELL of -15 at 55.58 on day 2
# Created CLOSE of -15 at 54.82 on day 8
# Created BUY of 15 55.63 on day 23
# Created CLOSE of 15 at 56.58 on day 4
# Created SELL of -15 at 57.04 on day 5
# Created CLOSE of -15 at 58.14 on day 10
# Created BUY of 15 56.31 on day 24
# Created CLOSE of 15 at 57.01 on day 1
# Created SELL of -15 at 57.19 on day 2
# Created CLOSE of -15 at 56.58 on day 8
# Created BUY of 15 57.95 on day 23
# Created CLOSE of 15 at 58.46 on day 1
# Created SELL of -15 at 58.65 on day 2
# Created CLOSE of -15 at 58.34 on day 8
# Created BUY of 15 60.38 on day 23
# Created BUY of 14 61.57 on day 26
# Created CLOSE of 14 at 61.28 on day 3
# Created SELL of -14 at 61.28 on day 4
# Created CLOSE of -14 at 58.99 on day 10
# Created BUY of 15 59.01 on day 24
# Created CLOSE of 15 at 61.29 on day 2
# Created SELL of -15 at 61.21 on day 3
# Created CLOSE of -15 at 61.41 on day 8
# Created BUY of 15 62.53 on day 23
# Created CLOSE of 15 at 62.06 on day 1
# Created SELL of -15 at 61.42 on day 4
# Created CLOSE of -15 at 61.06 on day 8
# Created BUY of 16 59.35 on day 25
# Created CLOSE of 16 at 61.25 on day 3
# Created SELL of -16 at 60.65 on day 4
# Created CLOSE of -16 at 61.21 on day 10
# Created BUY of 16 62.33 on day 24
# Created CLOSE of 16 at 61.7 on day 1
# Created SELL of -15 at 61.83 on day 2
# Created CLOSE of -15 at 61.99 on day 8
# Created BUY of 16 61.19 on day 23
# Created CLOSE of 16 at 61.16 on day 1
# Created SELL of -16 at 60.39 on day 2
# Created CLOSE of -16 at 60.75 on day 8
# Created BUY of 16 60.5 on day 23
# Created CLOSE of 16 at 59.74 on day 2
# Created SELL of -16 at 60.17 on day 3
# Created CLOSE of -16 at 60.05 on day 9
# Created BUY of 16 59.55 on day 23
# Created CLOSE of 16 at 60.95 on day 1
# Created SELL of -16 at 61.27 on day 2
# Created CLOSE of -16 at 61.81 on day 8
# Created BUY of 16 59.87 on day 23
# Created CLOSE of 16 at 61.0 on day 1
# Created SELL of -16 at 60.86 on day 4
# Created CLOSE of -16 at 61.31 on day 8
# Created BUY of 15 62.65 on day 25
# Created CLOSE of 15 at 63.12 on day 2
# Created SELL of -15 at 63.39 on day 3
# Created CLOSE of -15 at 64.13 on day 8
# Created BUY of 15 62.6 on day 23
# Created CLOSE of 15 at 64.26 on day 1
# Created SELL of -15 at 64.78 on day 2
# Created CLOSE of -15 at 65.38 on day 8
# Created BUY of 15 65.59 on day 23
# Created CLOSE of 15 at 62.45 on day 3
# Created SELL of -15 at 63.62 on day 4
# Created CLOSE of -15 at 63.8 on day 10
# Created BUY of 14 68.24 on day 24
# Created BUY of 13 70.25 on day 25
# Created CLOSE of 13 at 73.94 on day 1
# Created SELL of -13 at 74.22 on day 2
# Created CLOSE of -13 at 74.51 on day 8
# Created BUY of 12 81.89 on day 23
# Created CLOSE of 12 at 78.9 on day 2
# Created SELL of -12 at 76.86 on day 5
# Created CLOSE of -12 at 76.33 on day 8
# Created BUY of 13 73.03 on day 23
# Created CLOSE of 13 at 71.66 on day 2
# Created SELL of -13 at 69.96 on day 3
# Created CLOSE of -13 at 69.78 on day 9
# Created BUY of 12 71.32 on day 23
# Created CLOSE of 12 at 70.42 on day 2
# Created SELL of -12 at 69.95 on day 3
# Created CLOSE of -12 at 70.68 on day 9
# Created BUY of 12 70.25 on day 23
# Created CLOSE of 12 at 72.74 on day 1
# Created SELL of -12 at 71.85 on day 2
# Created CLOSE of -12 at 70.88 on day 8
# Created BUY of 13 69.47 on day 23
# Created CLOSE of 13 at 66.61 on day 1
# Created SELL of -13 at 66.83 on day 4
# Created CLOSE of -13 at 65.12 on day 8
# Created BUY of 14 63.19 on day 26
# Created CLOSE of 14 at 62.68 on day 1
# Created SELL of -14 at 63.02 on day 2
# Created CLOSE of -14 at 61.66 on day 8
# Created BUY of 14 64.46 on day 23
# Created CLOSE of 14 at 64.95 on day 1
# Created SELL of -14 at 65.1 on day 2
# Created CLOSE of -14 at 66.62 on day 8
# Created BUY of 14 62.83 on day 23
# Created CLOSE of 14 at 64.46 on day 3
# Created SELL of -15 at 63.95 on day 4
# Created CLOSE of -15 at 63.46 on day 10
# Created BUY of 14 66.13 on day 24
# Created CLOSE of 14 at 66.75 on day 1
# Created SELL of -14 at 67.72 on day 2
# Created CLOSE of -14 at 65.69 on day 8
# Created BUY of 14 67.03 on day 23
# Created CLOSE of 14 at 69.5 on day 1
# Created SELL of -14 at 69.01 on day 2
# Created CLOSE of -14 at 68.42 on day 8
# Created BUY of 15 66.18 on day 23
# Created CLOSE of 15 at 66.47 on day 2
# Created SELL of -16 at 65.8 on day 3
# Created CLOSE of -16 at 65.34 on day 9
# Created BUY of 15 66.43 on day 23
# Created CLOSE of 15 at 66.82 on day 1
# Created SELL of -15 at 66.88 on day 2
# Created CLOSE of -15 at 65.66 on day 8
# Created BUY of 16 63.59 on day 23
# Created CLOSE of 16 at 63.23 on day 4
# Created SELL of -16 at 63.64 on day 5
# Created CLOSE of -16 at 62.86 on day 8
# Created BUY of 16 64.47 on day 25
# Created CLOSE of 16 at 64.4 on day 1
# Created SELL of -16 at 64.58 on day 2
# Created CLOSE of -16 at 65.07 on day 8
# Created BUY of 16 63.92 on day 23
# Created CLOSE of 16 at 64.74 on day 1
# Created SELL of -16 at 64.65 on day 2
# Created CLOSE of -16 at 63.65 on day 8
# Created BUY of 16 64.45 on day 23
# Created CLOSE of 16 at 63.28 on day 1
# Created SELL of -17 at 62.23 on day 5
# Created CLOSE of -17 at 63.15 on day 8
# Created BUY of 16 64.1 on day 23
# Created CLOSE of 16 at 65.46 on day 3
# Created SELL of -16 at 66.63 on day 4
# Created CLOSE of -16 at 66.82 on day 10
# Created BUY of 15 70.02 on day 24
# Created CLOSE of 15 at 69.37 on day 1
# Created SELL of -15 at 68.71 on day 2
# Created CLOSE of -15 at 70.23 on day 8
# Created BUY of 14 71.09 on day 23
# Created CLOSE of 14 at 73.0 on day 1
# Created SELL of -14 at 72.42 on day 2
# Created CLOSE of -14 at 71.7 on day 8
# Created BUY of 14 71.69 on day 23
# Created CLOSE of 14 at 71.18 on day 2
# Created SELL of -14 at 71.59 on day 3
# Created CLOSE of -14 at 71.89 on day 9
# Created BUY of 13 76.45 on day 23
# Created CLOSE of 13 at 76.63 on day 1
# Created SELL of -13 at 75.82 on day 2
# Created CLOSE of -13 at 75.81 on day 8
# Created BUY of 13 75.85 on day 23
# Created CLOSE of 13 at 75.91 on day 1
# Created SELL of -13 at 76.11 on day 4
# Created CLOSE of -13 at 75.63 on day 8
# Created BUY of 14 73.78 on day 25
# Created CLOSE of 14 at 72.56 on day 1
# Created SELL of -14 at 73.51 on day 2
# Created CLOSE of -14 at 71.65 on day 8
# Created BUY of 15 70.96 on day 23
# Created CLOSE of 15 at 70.05 on day 1
# Created SELL of -15 at 69.86 on day 2
# Created CLOSE of -15 at 68.13 on day 8
# Created BUY of 16 67.88 on day 23
# Created CLOSE of 16 at 68.47 on day 3
# Created SELL of -16 at 68.55 on day 4
# Created CLOSE of -16 at 68.06 on day 10
# Created BUY of 16 67.11 on day 24
# Created CLOSE of 16 at 66.53 on day 1
# Created SELL of -16 at 66.55 on day 2
# Created CLOSE of -16 at 65.06 on day 8
# Created BUY of 16 67.05 on day 23
# Created CLOSE of 16 at 68.16 on day 1
# Created SELL of -16 at 67.12 on day 2
# Created CLOSE of -16 at 66.18 on day 8
# Created BUY of 16 68.7 on day 23
# Created CLOSE of 16 at 68.32 on day 1
# Created SELL of -16 at 68.39 on day 4
# Created CLOSE of -16 at 66.61 on day 8
# Created BUY of 16 68.88 on day 25
# Created CLOSE of 16 at 69.69 on day 2
# Created SELL of -16 at 70.08 on day 3
# Created CLOSE of -16 at 70.68 on day 9
# Created BUY of 16 71.28 on day 23
# Created CLOSE of 16 at 72.93 on day 1
# Created SELL of -16 at 71.54 on day 2
# Created CLOSE of -16 at 72.3 on day 8
# Created BUY of 16 72.74 on day 23
# Created CLOSE of 16 at 70.17 on day 1
# Created SELL of -16 at 70.33 on day 5
# Created CLOSE of -16 at 71.48 on day 8
# Created BUY of 15 71.2 on day 25
# Created CLOSE of 15 at 74.13 on day 1
# Created SELL of -15 at 76.36 on day 2
# Created CLOSE of -15 at 79.37 on day 8
# Created BUY of 13 82.26 on day 23
# Created CLOSE of 13 at 82.19 on day 1
# Created SELL of -13 at 84.86 on day 2
# Created CLOSE of -13 at 84.86 on day 8
# Created BUY of 12 91.14 on day 23
# Created CLOSE of 12 at 93.62 on day 3
# Created SELL of -13 at 92.43 on day 4
# Created CLOSE of -13 at 88.15 on day 10
# Created BUY of 14 85.69 on day 24
# Created CLOSE of 14 at 90.56 on day 1
# Created SELL of -14 at 89.43 on day 2
# Created CLOSE of -14 at 87.73 on day 8
# Created BUY of 13 92.93 on day 23
# Created CLOSE of 13 at 88.92 on day 1
# Created SELL of -13 at 90.17 on day 2
# Created CLOSE of -13 at 90.56 on day 8
# Created BUY of 13 89.88 on day 23
# Created CLOSE of 13 at 91.06 on day 3
# Created SELL of -13 at 89.98 on day 4
# Created CLOSE of -13 at 90.36 on day 9
# Created BUY of 13 88.63 on day 23
# Created CLOSE of 13 at 91.09 on day 1
# Created SELL of -13 at 91.05 on day 2
# Created CLOSE of -13 at 88.93 on day 8
# Created BUY of 14 89.22 on day 23
# Created CLOSE of 14 at 88.9 on day 1
# Created SELL of -14 at 89.74 on day 2
# Created CLOSE of -14 at 88.66 on day 8
# Created BUY of 14 86.72 on day 23
# Created CLOSE of 14 at 86.42 on day 2
# Created SELL of -15 at 84.92 on day 3
# Created CLOSE of -15 at 88.74 on day 9
# Created BUY of 13 90.56 on day 23
# Created CLOSE of 13 at 89.63 on day 1
# Created SELL of -13 at 90.26 on day 2
# Created CLOSE of -13 at 91.45 on day 8
# Created BUY of 12 95.01 on day 23
# Created CLOSE of 12 at 100.56 on day 1
# Created SELL of -12 at 99.77 on day 4
# Created CLOSE of -12 at 96.59 on day 8
# Created BUY of 13 97.85 on day 25
# Created CLOSE of 13 at 97.58 on day 2
# Created SELL of -13 at 96.83 on day 3
# Created CLOSE of -13 at 99.1 on day 9
# Created BUY of 12 101.11 on day 23
# Created CLOSE of 12 at 99.77 on day 1
# Created SELL of -12 at 100.34 on day 2
# Created CLOSE of -12 at 96.97 on day 8
# Created BUY of 13 96.79 on day 23
# Created CLOSE of 13 at 98.85 on day 4
# Created SELL of -13 at 98.38 on day 5
# Created CLOSE of -13 at 96.53 on day 10
# Created BUY of 13 95.11 on day 24
# Created CLOSE of 13 at 96.8 on day 1
# Created SELL of -13 at 96.67 on day 2
# Created CLOSE of -13 at 95.05 on day 8
# Created BUY of 14 95.45 on day 23
# Created CLOSE of 14 at 95.19 on day 1
# Created SELL of -14 at 95.12 on day 2
# Created CLOSE of -14 at 97.91 on day 8
# Created BUY of 13 96.64 on day 23
# Created CLOSE of 13 at 97.18 on day 3
# Created SELL of -13 at 97.74 on day 4
# Created CLOSE of -13 at 97.43 on day 10
# Created BUY of 14 95.13 on day 24
# Created CLOSE of 14 at 93.41 on day 2
# Created SELL of -14 at 92.14 on day 3
# Created CLOSE of -14 at 93.15 on day 8
# Created BUY of 13 93.82 on day 23
# Created CLOSE of 13 at 90.47 on day 1
# Created SELL of -13 at 91.63 on day 4
# Created CLOSE of -13 at 91.7 on day 8
# Created BUY of 13 93.43 on day 25
# Created CLOSE of 13 at 93.3 on day 1
# Created SELL of -13 at 92.8 on day 4
# Created CLOSE of -13 at 90.04 on day 8
# Created BUY of 14 91.98 on day 25
# Created CLOSE of 14 at 93.1 on day 1
# Created SELL of -14 at 92.72 on day 2
# Created CLOSE of -14 at 95.84 on day 8
# Created BUY of 13 96.32 on day 23
# Created CLOSE of 13 at 97.73 on day 1
# Created SELL of -13 at 97.6 on day 2
# Created CLOSE of -13 at 94.84 on day 8
# Created BUY of 14 91.92 on day 23
# Created CLOSE of 14 at 90.67 on day 3
# Created SELL of -14 at 89.83 on day 4
# Created CLOSE of -14 at 88.96 on day 10
# Created BUY of 14 85.99 on day 24
# Created CLOSE of 14 at 87.42 on day 1
# Created SELL of -14 at 87.36 on day 2
# Created CLOSE of -14 at 84.95 on day 8
# Created BUY of 15 86.22 on day 23
# Created CLOSE of 15 at 83.63 on day 1
# Created SELL of -15 at 84.55 on day 2
# Created CLOSE of -15 at 85.0 on day 8
# Created BUY of 15 82.78 on day 23
# Created CLOSE of 15 at 82.94 on day 3
# Created SELL of -15 at 82.76 on day 4
# Created CLOSE of -15 at 82.05 on day 9
# Created BUY of 15 84.11 on day 23
# Created CLOSE of 15 at 84.42 on day 1
# Created SELL of -15 at 84.55 on day 2
# Created CLOSE of -15 at 84.72 on day 8
# Created BUY of 15 86.42 on day 23
# Created CLOSE of 15 at 84.96 on day 1
# Created SELL of -15 at 85.04 on day 4
# Created CLOSE of -15 at 82.73 on day 8
# Created BUY of 15 83.37 on day 25
# Created CLOSE of 15 at 82.92 on day 2
# Created SELL of -15 at 83.22 on day 3
# Created CLOSE of -15 at 82.78 on day 9
# Created BUY of 15 83.18 on day 23
# Created CLOSE of 15 at 82.25 on day 2
# Created SELL of -15 at 82.25 on day 3
# Created CLOSE of -15 at 82.58 on day 8
# Created BUY of 15 85.97 on day 23
# Created BUY of 14 86.53 on day 24
# Created CLOSE of 14 at 88.24 on day 3
# Created SELL of -15 at 87.3 on day 4
# Created CLOSE of -15 at 86.44 on day 10
# Created BUY of 15 85.88 on day 24
# Created CLOSE of 15 at 88.21 on day 3
# Created SELL of -15 at 86.89 on day 4
# Created CLOSE of -15 at 85.8 on day 10
# Created BUY of 15 88.19 on day 24
# Created CLOSE of 15 at 87.52 on day 1
# Created SELL of -15 at 87.01 on day 2
# Created CLOSE of -15 at 88.72 on day 8
# Created BUY of 14 90.01 on day 23
# Created CLOSE of 14 at 91.09 on day 1
# Created SELL of -14 at 91.65 on day 2
# Created CLOSE of -14 at 90.75 on day 8
# Created BUY of 14 91.64 on day 23
# Created CLOSE of 14 at 92.09 on day 2
# Created SELL of -15 at 90.96 on day 3
# Created CLOSE of -15 at 90.84 on day 9
# Created BUY of 15 90.86 on day 23
# Created CLOSE of 15 at 91.77 on day 1
# Created SELL of -15 at 90.79 on day 2
# Created CLOSE of -15 at 92.15 on day 8
# Created BUY of 14 94.14 on day 23
# Created CLOSE of 14 at 93.88 on day 1
# Created SELL of -14 at 93.64 on day 4
# Created CLOSE of -14 at 94.67 on day 8
# Created BUY of 13 96.48 on day 25
# Created CLOSE of 13 at 95.88 on day 2
# Created SELL of -13 at 96.41 on day 3
# Created CLOSE of -13 at 95.1 on day 8
# Created BUY of 13 94.83 on day 23
# Created CLOSE of 13 at 97.35 on day 1
# Created SELL of -14 at 96.5 on day 2
# Created CLOSE of -14 at 98.31 on day 8
# Created BUY of 13 98.48 on day 23
# Created CLOSE of 13 at 98.19 on day 3
# Created SELL of -13 at 98.5 on day 4
# Created CLOSE of -13 at 97.94 on day 10
# Created BUY of 13 99.22 on day 24
# Created CLOSE of 13 at 100.52 on day 1
# Created SELL of -13 at 99.54 on day 2
# Created CLOSE of -13 at 101.4 on day 8
# Created BUY of 12 102.2 on day 23
# Created CLOSE of 12 at 105.55 on day 2
# Created SELL of -12 at 107.21 on day 5
# Created CLOSE of -12 at 107.49 on day 8
# Created BUY of 12 111.73 on day 23
# Created CLOSE of 12 at 114.21 on day 2
# Created SELL of -12 at 111.79 on day 3
# Created CLOSE of -12 at 108.62 on day 9
# Created BUY of 13 106.32 on day 23
# Created CLOSE of 13 at 105.6 on day 2
# Created SELL of -13 at 105.22 on day 3
# Created CLOSE of -13 at 103.74 on day 9
# Created BUY of 12 109.33 on day 23
# Created CLOSE of 12 at 110.21 on day 1
# Created SELL of -13 at 109.04 on day 2
# Created CLOSE of -13 at 109.37 on day 8
# Created BUY of 13 106.99 on day 23
# Created CLOSE of 13 at 103.64 on day 1
# Created SELL of -13 at 102.66 on day 4
# Created CLOSE of -13 at 102.39 on day 8
# Created BUY of 13 102.35 on day 26
# Created CLOSE of 13 at 101.46 on day 1
# Created SELL of -13 at 100.04 on day 2
# Created CLOSE of -13 at 98.39 on day 8
# Created BUY of 14 97.12 on day 23
# Created CLOSE of 14 at 97.06 on day 1
# Created SELL of -14 at 97.38 on day 2
# Created CLOSE of -14 at 100.98 on day 8
# Created BUY of 13 101.65 on day 23
# Created CLOSE of 13 at 103.94 on day 3
# Created SELL of -13 at 103.11 on day 4
# Created CLOSE of -13 at 103.31 on day 10
# Created BUY of 12 106.3 on day 24
# Created CLOSE of 12 at 102.88 on day 1
# Created SELL of -13 at 102.0 on day 2
# Created CLOSE of -13 at 101.91 on day 8
# Created BUY of 13 102.66 on day 23
# Created CLOSE of 13 at 104.6 on day 1
# Created SELL of -13 at 105.23 on day 2
# Created CLOSE of -13 at 103.04 on day 8
# Created BUY of 13 104.09 on day 23
# Created CLOSE of 13 at 103.25 on day 2
# Created SELL of -13 at 102.41 on day 3
# Created CLOSE of -13 at 100.19 on day 9
# Created BUY of 13 102.3 on day 23
# Created CLOSE of 13 at 104.22 on day 1
# Created SELL of -13 at 104.25 on day 2
# Created CLOSE of -13 at 103.35 on day 8
# Created BUY of 14 103.0 on day 23
# Created CLOSE of 14 at 103.26 on day 4
# Created SELL of -14 at 102.85 on day 5
# Created CLOSE of -14 at 104.89 on day 8
# Created BUY of 13 107.15 on day 25
# Created CLOSE of 13 at 107.91 on day 1
# Created SELL of -13 at 109.91 on day 2
# Created CLOSE of -13 at 112.01 on day 8
# Created BUY of 12 112.0 on day 23
# Created CLOSE of 12 at 109.61 on day 1
# Created SELL of -12 at 110.07 on day 2
# Created CLOSE of -12 at 110.94 on day 8
# Created BUY of 12 110.52 on day 23
# Created CLOSE of 12 at 111.77 on day 1
# Created SELL of -12 at 111.83 on day 4
# Created CLOSE of -12 at 112.9 on day 8
# Created BUY of 12 109.33 on day 25
# Created CLOSE of 12 at 109.54 on day 2
# Created SELL of -12 at 110.92 on day 3
# Created CLOSE of -12 at 112.15 on day 9
# Created BUY of 12 111.79 on day 23
# Created CLOSE of 12 at 112.0 on day 1
# Created SELL of -12 at 112.81 on day 2
# Created CLOSE of -12 at 114.45 on day 8
# Created BUY of 12 113.55 on day 23
# Created BUY of 12 116.6 on day 24
# Created BUY of 11 119.51 on day 27
# Created CLOSE of 11 at 120.94 on day 1
# Created SELL of -11 at 122.45 on day 5
# Created CLOSE of -11 at 123.54 on day 8
# Created BUY of 11 119.33 on day 25
# Created CLOSE of 11 at 120.47 on day 1
# Created SELL of -11 at 119.23 on day 2
# Created CLOSE of -11 at 119.17 on day 8
# Created BUY of 11 120.69 on day 23
# Created CLOSE of 11 at 120.69 on day 1
# Created SELL of -11 at 119.7 on day 2
# Created CLOSE of -11 at 118.98 on day 8
# Created BUY of 12 118.14 on day 23
# Created CLOSE of 12 at 118.34 on day 3
# Created SELL of -12 at 116.96 on day 4
# Created CLOSE of -12 at 115.16 on day 10
# Created BUY of 12 114.81 on day 24
# Created CLOSE of 12 at 113.54 on day 1
# Created SELL of -12 at 114.04 on day 2
# Created CLOSE of -12 at 112.75 on day 8
# Created BUY of 14 104.56 on day 23
# Created CLOSE of 14 at 103.11 on day 1
# Created SELL of -14 at 103.86 on day 2
# Created CLOSE of -14 at 103.33 on day 8
# Created BUY of 14 102.79 on day 23
# Created CLOSE of 14 at 104.17 on day 3
# Created SELL of -14 at 104.57 on day 4
# Created CLOSE of -14 at 106.08 on day 9
# Created BUY of 13 105.48 on day 23
# Created CLOSE of 13 at 103.92 on day 1
# Created SELL of -14 at 103.88 on day 2
# Created CLOSE of -14 at 106.66 on day 8
# Created BUY of 13 105.29 on day 23
# Created CLOSE of 13 at 104.45 on day 1
# Created SELL of -13 at 104.07 on day 2
# Created CLOSE of -13 at 102.97 on day 8
# Created BUY of 13 105.3 on day 23
# Created CLOSE of 13 at 106.6 on day 3
# Created SELL of -13 at 106.02 on day 4
# Created CLOSE of -13 at 106.25 on day 10
# Created BUY of 13 107.7 on day 24
# Created CLOSE of 13 at 106.3 on day 1
# Created SELL of -13 at 106.85 on day 2
# Created CLOSE of -13 at 105.91 on day 8
# Created BUY of 13 107.58 on day 23
# Created CLOSE of 13 at 109.23 on day 1
# Created SELL of -13 at 110.52 on day 2
# Created CLOSE of -13 at 109.61 on day 8
# Created BUY of 13 112.42 on day 23
# Created CLOSE of 13 at 109.73 on day 3
# Created SELL of -13 at 109.75 on day 5
# Created CLOSE of -13 at 108.35 on day 10
# Created BUY of 13 110.38 on day 24
# Created CLOSE of 13 at 110.12 on day 1
# Created SELL of -13 at 110.19 on day 2
# Created CLOSE of -13 at 110.11 on day 8
# Created BUY of 12 112.47 on day 23
# Created CLOSE of 12 at 112.22 on day 1
# Created SELL of -12 at 114.0 on day 5
# Created CLOSE of -12 at 114.21 on day 8
# Created BUY of 13 112.43 on day 25
# Created CLOSE of 13 at 110.25 on day 2
# Created SELL of -13 at 110.36 on day 3
# Created CLOSE of -13 at 109.99 on day 9
# Created BUY of 13 110.18 on day 23
# Created CLOSE of 13 at 110.91 on day 1
# Created SELL of -13 at 111.39 on day 2
# Created CLOSE of -13 at 112.34 on day 8
# Created BUY of 13 112.73 on day 24
# Created CLOSE of 13 at 112.74 on day 1
# Created SELL of -12 at 112.79 on day 4
# Created CLOSE of -12 at 112.86 on day 8
# Created BUY of 13 111.72 on day 26
# Created BUY of 12 113.17 on day 27
# Created CLOSE of 12 at 112.03 on day 2
# Created SELL of -12 at 112.56 on day 3
# Created CLOSE of -12 at 112.15 on day 8
# Created BUY of 13 110.44 on day 23
# Created CLOSE of 13 at 107.98 on day 1
# Created SELL of -13 at 106.97 on day 2
# Created CLOSE of -13 at 106.18 on day 8
# Created BUY of 13 105.68 on day 23
# Created CLOSE of 13 at 106.96 on day 1
# Created SELL of -13 at 106.09 on day 2
# Created CLOSE of -13 at 106.39 on day 8
# Created BUY of 13 107.72 on day 23
# Created CLOSE of 13 at 109.49 on day 2
# Created SELL of -13 at 108.64 on day 3
# Created CLOSE of -13 at 108.96 on day 9
# Created BUY of 13 106.44 on day 23
# Created CLOSE of 13 at 106.6 on day 1
# Created SELL of -13 at 106.49 on day 2
# Created CLOSE of -13 at 106.85 on day 8
# Created BUY of 14 106.18 on day 23
# Created CLOSE of 14 at 108.56 on day 1
# Created SELL of -14 at 107.77 on day 4
# Created CLOSE of -14 at 107.86 on day 8
# Created BUY of 14 109.01 on day 25
# Created CLOSE of 14 at 109.75 on day 2
# Created SELL of -13 at 110.34 on day 3
# Created CLOSE of -13 at 110.3 on day 9
# Created BUY of 14 107.87 on day 23
# Created CLOSE of 14 at 107.38 on day 1
# Created SELL of -14 at 107.53 on day 2
# Created CLOSE of -14 at 107.68 on day 8
# Created BUY of 13 110.63 on day 23
# Created CLOSE of 13 at 109.05 on day 4
# Created SELL of -13 at 108.75 on day 5
# Created CLOSE of -13 at 108.63 on day 10
# Created BUY of 14 106.11 on day 24
# Created CLOSE of 14 at 105.76 on day 1
# Created SELL of -14 at 106.4 on day 2
# Created CLOSE of -14 at 102.58 on day 8
# Created BUY of 15 103.73 on day 23
# Created CLOSE of 15 at 103.51 on day 1
# Created SELL of -15 at 102.22 on day 2
# Created CLOSE of -15 at 102.69 on day 8
# Created BUY of 14 105.09 on day 23
# Created CLOSE of 14 at 106.01 on day 3
# Created SELL of -14 at 107.79 on day 4
# Created CLOSE of -14 at 108.77 on day 10
# Created BUY of 14 111.25 on day 24
# Created CLOSE of 14 at 112.01 on day 2
# Created SELL of -14 at 113.29 on day 3
# Created CLOSE of -14 at 111.35 on day 8
# Created BUY of 14 110.33 on day 23
# Created CLOSE of 14 at 111.17 on day 1
# Created SELL of -14 at 110.68 on day 4
# Created CLOSE of -14 at 112.45 on day 8
# Created BUY of 14 111.4 on day 25
# Created CLOSE of 14 at 109.29 on day 1
# Created SELL of -14 at 110.15 on day 4
# Created CLOSE of -14 at 111.97 on day 8
# Created BUY of 13 115.18 on day 25
# Created CLOSE of 13 at 114.8 on day 1
# Created SELL of -13 at 115.01 on day 2
# Created CLOSE of -13 at 114.08 on day 8
# Created BUY of 13 113.14 on day 23
# Created CLOSE of 13 at 114.61 on day 1
# Created SELL of -13 at 114.06 on day 2
# Created CLOSE of -13 at 115.08 on day 8
# Created BUY of 12 118.09 on day 23
# Created CLOSE of 12 at 122.76 on day 3
# Created SELL of -12 at 121.36 on day 4
# Created CLOSE of -12 at 120.96 on day 10
# Created BUY of 12 122.73 on day 24
# Created CLOSE of 12 at 122.81 on day 1
# Created SELL of -12 at 123.76 on day 2
# Created CLOSE of -12 at 123.16 on day 8
# Created BUY of 12 121.86 on day 23
# Created CLOSE of 12 at 125.87 on day 1
# Created SELL of -12 at 127.03 on day 2
# Created CLOSE of -12 at 130.58 on day 8
# Created BUY of 11 135.82 on day 23
# Created CLOSE of 11 at 137.23 on day 3
# Created SELL of -11 at 137.43 on day 4
# Created CLOSE of -11 at 133.49 on day 9
# Created BUY of 12 132.24 on day 23
# Created CLOSE of 12 at 133.78 on day 1
# Created SELL of -12 at 134.11 on day 2
# Created CLOSE of -12 at 135.56 on day 8
# Created BUY of 12 130.25 on day 23
# Created CLOSE of 12 at 131.49 on day 1
# Created SELL of -12 at 129.76 on day 4
# Created CLOSE of -12 at 126.2 on day 8
# Created BUY of 12 131.25 on day 25
# Created CLOSE of 12 at 129.61 on day 2
# Created SELL of -12 at 132.32 on day 3
# Created CLOSE of -12 at 129.92 on day 9
# Created BUY of 12 128.07 on day 23
# Created CLOSE of 12 at 128.59 on day 2
# Created SELL of -12 at 130.57 on day 3
# Created CLOSE of -12 at 128.34 on day 8
# Created BUY of 13 132.28 on day 23
# Created CLOSE of 13 at 136.83 on day 3
# Created SELL of -13 at 134.98 on day 4
# Created CLOSE of -13 at 136.16 on day 10
# Created BUY of 12 141.25 on day 24
# Created CLOSE of 12 at 144.94 on day 2
# Created SELL of -12 at 147.19 on day 3
# Created CLOSE of -12 at 161.27 on day 9
# Created BUY of 10 156.29 on day 23
# Created CLOSE of 10 at 157.5 on day 1
# Created SELL of -10 at 158.5 on day 2
# Created CLOSE of -10 at 155.66 on day 8
# Created BUY of 10 160.7 on day 23
# Created CLOSE of 10 at 158.56 on day 1
# Created SELL of -10 at 157.82 on day 4
# Created CLOSE of -10 at 154.81 on day 8
# Created BUY of 11 154.2 on day 26
# Created CLOSE of 11 at 153.41 on day 1
# Created SELL of -11 at 152.85 on day 2
# Created CLOSE of -11 at 148.14 on day 8
# Created BUY of 11 152.48 on day 23
# Created CLOSE of 11 at 154.66 on day 1
# Created SELL of -11 at 154.83 on day 2
# Created CLOSE of -11 at 155.73 on day 8
# Created BUY of 10 160.66 on day 23
# Created CLOSE of 10 at 161.02 on day 3
# Created SELL of -10 at 162.56 on day 4
# Created CLOSE of -10 at 160.24 on day 10
# Created BUY of 11 157.21 on day 24
# Created CLOSE of 11 at 155.43 on day 1
# Created SELL of -11 at 156.91 on day 2
# Created CLOSE of -11 at 155.31 on day 8
# Created BUY of 11 156.03 on day 23
# Created CLOSE of 11 at 155.11 on day 1
# Created SELL of -11 at 154.54 on day 2
# Created CLOSE of -11 at 152.04 on day 8
# Created BUY of 11 150.03 on day 23
# Created CLOSE of 11 at 150.74 on day 2
# Created SELL of -11 at 149.86 on day 3
# Created CLOSE of -11 at 148.34 on day 9
# Created BUY of 12 152.82 on day 23
# Created CLOSE of 12 at 149.86 on day 1
# Created SELL of -12 at 148.67 on day 2
# Created CLOSE of -12 at 149.71 on day 8
# Created BUY of 12 149.23 on day 23
# Created CLOSE of 12 at 150.06 on day 4
# Created SELL of -12 at 148.94 on day 5
# Created CLOSE of -12 at 144.13 on day 8
# Created BUY of 12 146.37 on day 25
# Created CLOSE of 12 at 144.95 on day 1
# Created SELL of -12 at 144.01 on day 2
# Created CLOSE of -12 at 141.78 on day 8
# Created BUY of 13 135.19 on day 23
# Created CLOSE of 13 at 134.68 on day 1
# Created SELL of -13 at 134.69 on day 2
# Created CLOSE of -13 at 131.59 on day 8
# Created BUY of 14 131.27 on day 23
# Created CLOSE of 14 at 131.47 on day 1
# Created SELL of -14 at 130.9 on day 5
# Created CLOSE of -14 at 131.95 on day 8
# Created BUY of 13 133.91 on day 23
# Created CLOSE of 13 at 132.63 on day 3
# Created SELL of -13 at 133.53 on day 4
# Created CLOSE of -13 at 131.96 on day 10
# Created BUY of 14 132.3 on day 24
# Created CLOSE of 14 at 132.52 on day 1
# Created SELL of -14 at 132.83 on day 2
# Created CLOSE of -14 at 134.67 on day 8
# Created BUY of 13 137.37 on day 23
# Created CLOSE of 13 at 138.42 on day 1
# Created SELL of -13 at 139.25 on day 2
# Created CLOSE of -13 at 142.69 on day 8
# Created BUY of 12 142.57 on day 23
# Created CLOSE of 12 at 144.83 on day 2
# Created SELL of -12 at 144.91 on day 3
# Created CLOSE of -12 at 141.55 on day 9
# Created BUY of 13 144.62 on day 23
# Created CLOSE of 13 at 143.3 on day 1
# Created SELL of -13 at 143.93 on day 2
# Created CLOSE of -13 at 142.38 on day 8
# Created BUY of 13 142.79 on day 23
# Created CLOSE of 13 at 140.08 on day 1
# Created SELL of -13 at 139.72 on day 4
# Created CLOSE of -13 at 136.73 on day 8
# Created BUY of 13 138.69 on day 25
# Created CLOSE of 13 at 141.31 on day 1
# Created SELL of -13 at 141.93 on day 2
# Created CLOSE of -13 at 143.8 on day 8
# Created BUY of 13 139.43 on day 23
# Created CLOSE of 13 at 147.18 on day 1
# Created SELL of -13 at 147.36 on day 2
# Created CLOSE of -13 at 143.36 on day 8
# Created BUY of 14 143.65 on day 23
# Created CLOSE of 14 at 139.57 on day 3
# Created SELL of -14 at 138.99 on day 4
# Created CLOSE of -14 at 137.93 on day 10
# Created BUY of 14 137.78 on day 24
# Created CLOSE of 14 at 137.26 on day 1
# Created SELL of -14 at 137.73 on day 2
# Created CLOSE of -14 at 133.82 on day 8
# Created BUY of 14 132.38 on day 23
# Created CLOSE of 14 at 137.04 on day 1
# Created SELL of -15 at 132.35 on day 2
# Created CLOSE of -15 at 133.61 on day 8
# Created BUY of 15 127.53 on day 23
# Created CLOSE of 15 at 128.58 on day 1
# Created SELL of -15 at 127.69 on day 4
# Created CLOSE of -15 at 121.53 on day 8
# Created BUY of 18 117.71 on day 25
# Created BUY of 17 118.9 on day 26
# Created CLOSE of 17 at 114.01 on day 2
# Created SELL of -18 at 114.78 on day 3
# Created CLOSE of -18 at 111.57 on day 9
# Created BUY of 18 113.41 on day 23
# Created CLOSE of 18 at 113.28 on day 1
# Created SELL of -18 at 113.34 on day 2
# Created CLOSE of -18 at 111.21 on day 8
# Created BUY of 19 111.25 on day 23

# %%
# Get the strategy returns as a dictionary
returns_dict = backtest_result[0].analyzers.time_return.get_analysis()

# Convert the dictionary to a DataFrame
returns_df = (
    pd.DataFrame(
        list(returns_dict.items()),
        columns = ["date", "return"]
    )
    .set_index("date")
)

# %%
# Step 3: Assess the results using key performance metrics

# Trading takes time, money, and effort. To make sure you’re better off not being long TLT, compare the strategy results to a long-only strategy.

# QuantStats makes it easy.

# QuantStats is a library jam-packed with trading performance and risk metrics. One of the best parts of Backtrader is that it works well with QuantStats.

# Here’s how to use it.

bench = openbb.stocks.load(
    "TLT",
    start_date="2002-01-01",
    end_date="2022-06-30"
)["Adj Close"]

qs.reports.metrics(
    returns_df,
    benchmark=bench,
    mode="full"
)
# Out:
# Loading Daily data for TLT with starting period 2002-07-30.
#                            Strategy     Benchmark
# -------------------------  -----------  -----------
# Start Period               2002-07-30   2002-07-30
# End Period                 2022-06-29   2022-06-29
# Risk-Free Rate             0.0%         0.0%
# Time in Market             55.0%        4.0%
#
# Cumulative Return          112.88%      -100.0%
# CAGR﹪                     3.86%        -100.0%
#
# Sharpe                     0.47         -0.2
# Prob. Sharpe Ratio         98.13%       5.6%
# Smart Sharpe               0.45         -0.19
# Sortino                    0.67         -0.2
# Smart Sortino              0.65         -0.19
# Sortino/√2                 0.48         -0.14
# Smart Sortino/√2           0.46         -0.14
# Omega                      1.11         1.11
#
# Max Drawdown               -27.79%      -100.0%
# Longest DD Days            2586         7048
# Volatility (ann.)          8.98%        22.53%
# R^2                        0.0          0.0
# Information Ratio          0.02         0.02
# Calmar                     0.14         -1.0
# Skew                       -0.11        -69.74
# Kurtosis                   7.46         4913.45
#
# Expected Daily %           0.02%        -100.0%
# Expected Monthly %         0.32%        -100.0%
# Expected Yearly %          3.66%        -100.0%
# Kelly Criterion            -11.76%      16.96%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -0.91%       -2.35%
# Expected Shortfall (cVaR)  -0.91%       -2.35%
#
# Max Consecutive Wins       9            9
# Max Consecutive Losses     10           5
# Gain/Pain Ratio            0.11         -0.61
# Gain/Pain (1M)             0.48         -0.84
#
# Payoff Ratio               0.75         0.85
# Profit Factor              1.11         0.39
# Common Sense Ratio         1.21         -
# CPC Index                  0.43         0.2
# Tail Ratio                 1.08         -
# Outlier Win Ratio          5.1          96.7
# Outlier Loss Ratio         1.72         0.45
#
# MTD                        1.64%        0.0%
# 3M                         6.65%        0.0%
# 6M                         5.81%        0.0%
# YTD                        5.89%        0.0%
# 1Y                         16.31%       0.0%
# 3Y (ann.)                  10.89%       0.0%
# 5Y (ann.)                  8.09%        0.0%
# 10Y (ann.)                 5.04%        0.0%
# All-time (ann.)            3.86%        -100.0%
#
# Best Day                   3.76%        2.48%
# Worst Day                  -5.31%       -100.0%
# Best Month                 8.81%        5.51%
# Worst Month                -7.19%       -100.0%
# Best Year                  16.57%       9.72%
# Worst Year                 -12.93%      -100.0%
#
# Avg. Drawdown              -2.64%       -11.25%
# Avg. Drawdown Days         84           723
# Recovery Factor            4.06         -1.0
# Ulcer Index                0.11         0.98
# Serenity Index             0.29         -0.01
#
# Avg. Up Month              2.26%        4.35%
# Avg. Down Month            -3.64%       -0.75%
# Win Days %                 52.19%       61.88%
# Win Month %                58.33%       44.44%
# Win Quarter %              65.0%        50.0%
# Win Year %                 71.43%       50.0%
#
# Beta                       -0.0         -
# Alpha                      0.04         -
# Correlation                -0.11%       -
# Treynor Ratio              -258472.28%  -
